# %% [markdown]
# #### 1. urllib.parse.quote( ) : GET 요청시 한글 URL 인코딩
# #### 2. urllib.request.urlopen( ) : HTTP 요청
# #### 3. reponse.getcode( ):응답코드 200이면 OK ,  4http://book.daum.net/search/bookSearch.do?query=04면 FIle Not Found
# #### 4. response.read( ) : html을 읽어옴

# %%
import urllib.request 

search_addr = "http://book.daum.net/search/bookSearch.do?query="
search_word = "파이썬"
search_word_enc = urllib.parse.quote(search_word)
print(search_word_enc)
URL = search_addr + search_word_enc
req = urllib.request.Request(URL)
response = urllib.request.urlopen(req)
status_code = response.getcode()
html_data = response.read()
# Out:
# %ED%8C%8C%EC%9D%B4%EC%8D%AC

# %%
print(status_code)
# Out:
# 200

# %%
print(response)

# %%
print(html_data)
# Out:
# b'<!DOCTYPE html>\n<html lang="ko" class="os_mac chrome pc version_56_0_2924_87">\n<head>\n<meta charset="utf-8">\n<title>Daum \xec\x9b\x90\xed\x95\x98\xec\x8b\x9c\xeb\x8a\x94 \xed\x8e\x98\xec\x9d\xb4\xec\xa7\x80\xeb\xa5\xbc \xec\xb0\xbe\xec\x9d\x84 \xec\x88\x98\xea\xb0\x80 \xec\x97\x86\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4.</title>\n<meta http-equiv="X-UA-Compatible" content="IE=Edge">\n<style type="text/css">\nbody,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,button{margin:0;padding:0}\nfieldset,img{border:0 none}\ndl,ul,ol,menu,li{list-style:none}\nblockquote, q{quotes: none}\nblockquote:before, blockquote:after,q:before, q:after{content:\'\';content:none}\ninput,select,textarea,button{vertical-align:middle}\ninput::-ms-clear{display:none}\nbutton{border:0 none;background-color:transparent;cursor:pointer}\nbody{background:#fbfbfc}\nbody,th,td,input,select,textarea,button{font-size:12px;line-height:1.5;font-family:Appl
# ...

# %% [markdown]
# ### 예외 처리

# %%
import requests

URL = "http://book.daum.net/search/bookSearch.do"
params = {'query' : '파이썬'}
headers = {'User-Agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 6_0 like Mac OS X) AppleWebKit/536.26 (KHTML, like Gecko) Version/6.0 Mobile/10A5376e Safari/8536.25'}

response = requests.get(URL, headers=headers , params = params)
print(dir(response))

status_code = response.status_code
if status_code == 200:
    html_data = response.text
    print(response.url)
    print(status_code)
else:
    print("Error Code is : " + str(status_code))
    print("Error is That Reason : " + str(response.reason))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# http://status.daum.net/error/error404.html
# 200

# %%
import requests
from bs4 import BeautifulSoup as bs

URL = "https://search.daum.net/search"
params = {'w': 'book', 'nil_search' : 'btn', 'DA' : 'NTB', 'enc': 'utf8', 'q' : '파이썬' }

res = requests.get(URL , params = params )
html_content = bs(res.content, 'html.parser')
print(html_content.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="unix unknown" lang="ko" xmlns="http://www.w3.org/1999/xhtml">
#  <head profile="http://a9.com/-/spec/opensearch/1.1/">
#   <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="off" name="autocomplete"/>
#   <meta content="always" name="referrer"/>
#   <meta content="telephone=no" name="format-detection">
#    <meta content="파이썬 – Daum 검색" property="og:title"/>
#    <meta content="https://search.daum.net/search?w=book&amp;q=%ED%8C%8C%EC%9D%B4%EC%8D%AC" property="og:url"/>
#    <meta content="Daum 검색에서 파이썬에 대한 최신정보를 찾아보세요." property="og:description"/>
#    <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" property="og:image"/>
#    <meta content="다음검색" property="og:site_name"/>
#    <title>
#     파이썬 – Daum 검색
#    </title>
# ...

# %%
html_title = html_content.title
print(html_title.prettify())

html_body_ul = html_content.body.ul
print(html_body_ul)
# Out:
# <title>
#  Daum 쇼핑하우
# </title>
#
# <ul class="#gnb_category gnb_shopping _GL" data-gg="{lk:pc_gnb_cate}"> <!-- 2014-11-17 선택한 gnb에 on 클래스 넣어주세요. -->
# <li class="fst"><a class="link_gnb link_gnb1" data-group="all" href="javascript:;"><span class="tit_all">전체</span><span class="ico_comm2"></span></a></li>
# <li class=""><a class="link_gnb link_gnb2" data-group="fashion" href="javascript:;">패션/뷰티<span class="ico_tail"></span></a></li>
# <li class=""><a class="link_gnb link_gnb3" data-group="electric" href="javascript:;">가전/컴퓨터<span class="ico_tail"></span></a></li>
# <li class=""><a class="link_gnb link_gnb4" data-group="furniture" href="javascript:;">가구/생활/건강<span class="ico_tail"></span></a></li>
# <li class=""><a class="link_gnb link_gnb5" data-group="food" href="javascript:;">식품/유아동<span class="ico_tail"></span></a></li>
# <li class=""><a class="link_gnb link_gnb6" data-group="travel" href="javascript:;">여행/레저/자동차<span class="ico_tail"></span></a></li>
# </ul>

# %%
import requests
from bs4 import BeautifulSoup as bs

URL = "https://search.daum.net/search"
params = {'w': 'book', 'nil_search' : 'btn', 'DA' : 'NTB', 'enc': 'utf8', 'q' : '파이썬' }

res = requests.get(URL , params = params )
html_content = bs(res.content, 'html.parser')
# print(html_content.prettify())

html_title = html_content('title')
print(html_title)

html_body_ul = html_content.body('ul')
print(html_body_ul)
# Out:
# [<title>파이썬 – Daum 검색</title>]
# [<ul class="gnb_search">
# <li class="">
# <a class="tab tab_total" href="?w=tot&amp;q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;DA=NTB" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'><span class="inner_tab"><span class="txt_tab">통합검색</span></span></a>
# </li>
# <li class="">
# <a class="tab tab_img" href="?w=img&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%ED%8C%8C%EC%9D%B4%EC%8D%AC" onclick='smartLog(this, "pg=1&amp;r=2&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">이미지</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_vclip" href="?w=vclip&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%ED%8C%8C%EC%9D%B4%EC%8D%AC" onclick='smartLog(this, "pg=1&amp;r=3&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">동영상</span></span>
# </a>
# </li>
# <li class="">
# ...

# %% [markdown]
# #### 일치하는 태그 숫자 제한
# #### 하나만 검색 : find('태그명')

# %%
html_body_ul = html_content.find('ul')
print(html_body_ul)
# Out:
# <ul class="gnb_search">
# <li class="">
# <a class="tab tab_total" href="?w=tot&amp;q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;DA=NTB" onclick='smartLog(this, "pg=1&amp;r=1&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'><span class="inner_tab"><span class="txt_tab">통합검색</span></span></a>
# </li>
# <li class="">
# <a class="tab tab_img" href="?w=img&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%ED%8C%8C%EC%9D%B4%EC%8D%AC" onclick='smartLog(this, "pg=1&amp;r=2&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">이미지</span></span>
# </a>
# </li>
# <li class="">
# <a class="tab tab_vclip" href="?w=vclip&amp;nil_search=btn&amp;DA=NTB&amp;enc=utf8&amp;q=%ED%8C%8C%EC%9D%B4%EC%8D%AC" onclick='smartLog(this, "pg=1&amp;r=3&amp;p=1&amp;rc=1&amp;dc=NTB&amp;at=more", event);'>
# <span class="inner_tab"><span class="txt_tab">동영상</span></span>
# </a>
# </li>
# <li class="">
# ...

# %%
html_body_ul = html_content.find_all('meta')
for i in html_body_ul:
    print(i)
# Out:
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="파이썬 – Daum 검색" property="og:title"/>
# <meta content="https://search.daum.net/search?w=book&amp;q=%ED%8C%8C%EC%9D%B4%EC%8D%AC" property="og:url"/>
# <meta content="Daum 검색에서 파이썬에 대한 최신정보를 찾아보세요." property="og:description"/>
# <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" property="og:image"/>
# <meta content="다음검색" property="og:site_name"/>
# <title>파이썬 – Daum 검색</title>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="Daum" type="application/opensearchdescription+xml"/>
# <link charset="utf-8" href="//search1.daumcdn.net/search/statics/common/css/2019/p_common.0528040406.css" rel="stylesheet" type="text/css"/>
# ...

# %%
html_body_ul = html_content.find_all('meta', limit = 4)
for i in html_body_ul:
    print(i)
# Out:
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
